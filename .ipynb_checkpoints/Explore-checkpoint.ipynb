# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
income = pd.read_csv('Datasets/Income2.csv')

# %%
income.head()
# Out:
#    Unnamed: 0  Education   Seniority     Income
# 0           1  21.586207  113.103448  99.917173
# 1           2  18.275862  119.310345  92.579135
# 2           3  12.068966  100.689655  34.678727
# 3           4  17.034483  187.586207  78.702806
# 4           5  19.931034   20.000000  68.009922

# %%
plt.plot(income['Seniority'], income['Income'], 'kx')

# %%
auto = pd.read_csv('Datasets/Auto.csv')

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
credit = pd.read_csv('Datasets/Credit.csv', index_col=0)

# %%
credit.head()  # Estimate credit limit
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 1   14.891   3606     283      2   34         11    Male      No     Yes
# 2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 3  104.593   7075     514      4   71         11    Male      No      No
# 4  148.924   9504     681      3   36         11  Female      No      No
# 5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580
# 4      Asian      964
# 5  Caucasian      331

# %%
sns.scatterplot(x='Income', y='Age', data=credit, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Age'>

# %%
plt.plot(credit['Income'], credit['Limit'], 'kx')
plt.show()

# %%
heart = pd.read_csv('Datasets/Heart.csv', index_col=0) # predict AHD

# %%
heart.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 1   63    1       typical     145   233    1        2    150      0      2.3
# 2   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 3   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 4   37    1    nonanginal     130   250    0        0    187      0      3.5
# 5   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 1      3  0.0       fixed   No
# 2      2  3.0      normal  Yes
# 3      2  2.0  reversable  Yes
# 4      3  0.0      normal   No
# 5      1  0.0      normal   No

# %%
sns.scatterplot(x='MaxHR', y='RestBP', data=heart, hue='AHD')
plt.show()

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data, 
                  columns=['sl', 'sw', 'pl', 'pw'])
df['Species'] = data.target

# %%
df = df[df['Species'] != 1]

# %%
sns.scatterplot(x='pl', y='pw', data=df, hue='Species')
plt.show()
